# %%
from google.colab import drive
#import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
drive.mount('/content/drive')
folder = '/content/drive/MyDrive/conserta-avioes'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv(folder+"/dataset_aumentado.csv")
dados
# Out:
#       Grupo                                              Frase  Tipo
# 0         0                ENGINE IDLE OVERRIDE KILLED ENGINE.  orig
# 1         1  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...  orig
# 2         2  HOLDING SHORT OF RUNWAY, AFTER COMPLETION OF R...  orig
# 3         3                          #1 ENGINE BAFFLE CRACKED.  orig
# 4         4                RIGHT MAGNETOS BLAST TUBE FELL OFF.  orig
# ...     ...                                                ...   ...
# 8115   1626  Left-side pushrod and rocker on the #3 engine ...   var
# 8116   1627  Exhaust rocker on cylinder No. 1 of the right-...   var
# 8117   1627  The right engine’s #1 cylinder exhaust rocker ...   var
# 8118   1627  Found the exhaust rocker on cylinder 2 of the ...   var
# 8119   1627  Right-hand engine cylinder 3 exhaust rocker sh...   var
#
# [8120 rows x 3 columns]

# %%
dados['Frase'] = dados['Frase'].apply(lambda x:x.strip())

# %%
dados = dados.loc[dados['Frase'].apply(lambda x: len(x)>0)]

# %%
indices = dados.loc[dados['Tipo']=='var','Grupo'].unique()

# %%
len(indices)
# Out:
# 1614

# %%
old_indices = dados['Grupo'].unique()

# %%
len(old_indices)
# Out:
# 1628

# %%
indices_treino, indices_val_teste = train_test_split(indices,test_size=0.2,shuffle=True)

# %%
len(indices_treino)
# Out:
# 1291

# %%
len(indices_val_teste)
# Out:
# 323

# %%
indices_val_teste
# Out:
# array([1541, 1580,  772,  475,   38, 1128, 1453,  154,  818,  538,  488,
#          30, 1192, 1225,  715, 1538,  413, 1585, 1070,   56,   24,  235,
#        1493,  680,  499,  287,  108,   71, 1080, 1043,  209,  902, 1554,
#        1130,  126, 1454,  675,  590, 1186,  929,  726, 1589,  182,  384,
#        1385, 1184, 1185,  999,    6,  810,  721, 1581, 1252,  834,  599,
#        1349,  635,   42, 1489, 1455,  473, 1145,  415,  167, 1125, 1388,
#         742, 1377,  231,  865, 1621,  139, 1341,  767,  731,  353, 1559,
#         498,   90,  119,  355,    9,  642,  917, 1384, 1012, 1537,  329,
#         141,  567,  295, 1504, 1380, 1518,  373, 1014,  992, 1034,  813,
#        1138,   44, 1361,  380,  412,  802,   84, 1073, 1612,  446,  703,
#        1346,  605,  979, 1173,  955, 1270,   26, 1115, 1107, 1112, 1354,
#        1605, 1222,  853,  862, 1260,  743,  718, 1550, 1482,  339, 1218,
#         302,  200,  163,  791,  747, 1423, 1490,  577, 1360,  410,  667,
# ...

# %%
indices_val, indices_teste = train_test_split(indices_val_teste,test_size=0.5,shuffle=True)
indices_teste
# Out:
# array([  56, 1272, 1125,  896, 1221, 1092,  288,    7,  223,  403,  999,
#         657,  373, 1031,  511, 1308,    6, 1453,   22, 1130,  320, 1443,
#        1070,  210,  761,  680, 1196,  469, 1341,  410, 1538,  271,  642,
#        1354, 1150,   23,  287,  567, 1340, 1559, 1621,  802,  703,  919,
#         163,  154,  492,  934,  368,  902,  111,  759, 1550, 1440, 1321,
#         893,  731, 1573,  441, 1145,  367,   66, 1218,  721, 1529, 1222,
#        1014,  498,  726,  715,  300,   44, 1011,  605,  372,  139,  198,
#         309,  966, 1541,  353,  993,  577,   16,  385,  412,  219,  767,
#        1402,  166, 1418,  675,  798, 1175,  736, 1225,  853,  370,  891,
#        1388,  627,  201,  226,  595, 1398,  135,   30,  742,  256,  590,
#        1504, 1020,  495,  413,  958,  718, 1372,  826, 1299, 1422,  629,
#         772, 1034,  667,  295,  465,  771,  681,  765,  573,  282, 1385,
#         747,  665,  810, 1518,  476, 1124,  710, 1585, 1115, 1019,  955,
# ...

# %%
len(indices_teste)
# Out:
# 162

# %%
dataset_teste = dados[dados['Grupo'].isin(indices_teste)]
dataset_teste
# Out:
#       Grupo                                              Frase  Tipo
# 6         6              RIGHT ENGINE #4 AIR BAFFLE IS CRACKED  orig
# 7         7  RIGHT ENGINE FORWARD ALTERNATOR ATTACH BOLT LO...  orig
# 16       16                 AFTER LANDING, A/C IDLE @ 970 RPM.  orig
# 22       22  TOP FRONT RIGHT BAFFLE, BAFFLE SEAL RIVET PULL...  orig
# 23       23  ROUGH RUNNING ENGINE ON START. ENGINE RAN SMOO...  orig
# ...     ...                                                ...   ...
# 8035   1606  #1 engine backbone bolt leaking a small amount...   var
# 8092   1621  Compression on the right engine’s No.4 cylinde...   var
# 8093   1621  The right-side engine’s #3 cylinder only made ...   var
# 8094   1621  Left engine cylinder 4 compression was recorde...   var
# 8095   1621  Cylinder No.2 on the right engine showed a 40/...   var
#
# [810 rows x 3 columns]

# %%
dataset_teste.loc[dataset_teste['Tipo']=='orig']
# Out:
#       Grupo                                              Frase  Tipo
# 6         6              RIGHT ENGINE #4 AIR BAFFLE IS CRACKED  orig
# 7         7  RIGHT ENGINE FORWARD ALTERNATOR ATTACH BOLT LO...  orig
# 16       16                 AFTER LANDING, A/C IDLE @ 970 RPM.  orig
# 22       22  TOP FRONT RIGHT BAFFLE, BAFFLE SEAL RIVET PULL...  orig
# 23       23  ROUGH RUNNING ENGINE ON START. ENGINE RAN SMOO...  orig
# ...     ...                                                ...   ...
# 1573   1573  LOWER BLACK SEAL ON ENGINE, WORN AT ENGINE INT...  orig
# 1585   1585  #3 CYLINDER EXHAUST VALVE FAILED  (EX CLEARNAC...  orig
# 1589   1589       RIGHT ENGINE #3 CYLINDER HAS NO COMPRESSION.  orig
# 1606   1606     RIGHT ENGINE BACKBONE BOLT LEAKS A LITTLE OIL.  orig
# 1621   1621        RIGHT ENGINE #4 CYLINDER COMPRESSION 40/80.  orig
#
# [162 rows x 3 columns]

# %%
dataset_teste.loc[dataset_teste['Tipo']=='var']
# Out:
#       Grupo                                              Frase Tipo
# 1652      6  Cracked air baffle detected on the right engin...  var
# 1653      6  Found a crack in the left engine’s #3 air baff...  var
# 1654      6  The air baffle on engine #2 (right side) shows...  var
# 1655      6              Left engine #4 air baffle is cracked.  var
# 1656      7  The forward alternator attach bolt on the righ...  var
# ...     ...                                                ...  ...
# 8035   1606  #1 engine backbone bolt leaking a small amount...  var
# 8092   1621  Compression on the right engine’s No.4 cylinde...  var
# 8093   1621  The right-side engine’s #3 cylinder only made ...  var
# 8094   1621  Left engine cylinder 4 compression was recorde...  var
# 8095   1621  Cylinder No.2 on the right engine showed a 40/...  var
#
# [648 rows x 3 columns]

# %%
162*4
# Out:
# 648

# %%
dataset_teste.to_csv(folder+"/dataset_teste.csv",index=False)

# %%
dataset_val = dados[dados['Grupo'].isin(indices_val)]
dataset_val
# Out:
#       Grupo                                              Frase  Tipo
# 2         2  HOLDING SHORT OF RUNWAY, AFTER COMPLETION OF R...  orig
# 9         9  IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIG...  orig
# 18       18  LAST DAILY SHUT DOWN IDLE OVER RIDE SPEED CHEC...  orig
# 24       24        OIL FOUND ON ENTIRE RIGHT SIDE OF FUSELAGE.  orig
# 26       26  BAFFLE SEALS UNDER BOTH PROP GOVERNORS ARE LOOSE.  orig
# ...     ...                                                ...   ...
# 8031   1605    Noted rough engine performance; feels unsteady.   var
# 8056   1612  Suspected crack in cylinder No. 1 of the right...   var
# 8057   1612  Looks like the left engine’s #2 cylinder may b...   var
# 8058   1612  Inspection indicates a possible crack in the #...   var
# 8059   1612  Possible crack found in cylinder 4 of the left...   var
#
# [805 rows x 3 columns]

# %%
dataset_val.groupby('Tipo').count()
# Out:
#       Grupo  Frase
# Tipo
# orig    161    161
# var     644    644

# %%
161*4
# Out:
# 644

# %%
dataset_val.to_csv(folder+"/dataset_validacao.csv",index=False)

# %%
dataset_treino = dados[dados['Grupo'].isin(indices_treino)]
dataset_treino
# Out:
#       Grupo                                              Frase  Tipo
# 0         0                ENGINE IDLE OVERRIDE KILLED ENGINE.  orig
# 1         1  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...  orig
# 3         3                          #1 ENGINE BAFFLE CRACKED.  orig
# 4         4                RIGHT MAGNETOS BLAST TUBE FELL OFF.  orig
# 5         5  ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN EN...  orig
# ...     ...                                                ...   ...
# 8115   1626  Left-side pushrod and rocker on the #3 engine ...   var
# 8116   1627  Exhaust rocker on cylinder No. 1 of the right-...   var
# 8117   1627  The right engine’s #1 cylinder exhaust rocker ...   var
# 8118   1627  Found the exhaust rocker on cylinder 2 of the ...   var
# 8119   1627  Right-hand engine cylinder 3 exhaust rocker sh...   var
#
# [6455 rows x 3 columns]

# %%
dataset_treino.groupby('Tipo').count()
# Out:
#       Grupo  Frase
# Tipo
# orig   1291   1291
# var    5164   5164

# %%
1291*4
# Out:
# 5164

# %%
dataset_treino.to_csv(folder+"/dataset_treino.csv",index=False)
